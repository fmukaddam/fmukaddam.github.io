# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * There is a negative correlation of -0.86 between maximum temperature and latitude in the northern hemisphere. The farther the place from the equator, the lower the temperature and hence this is an expected outcome. However, the correlation between temperature and latitude is positive in the southern hemisphere since the latitude increases as we approach the equator.
# * The datasets for cloudiness and wind speed show some outliers. They do not have any but correlation to latitude or proximity to the equator.
# * There is a strong correlation between humidity and latitude in the northern hemisphere. Humidity increases as we go closer to the latitude due to high temperatures.

# %%
# Import Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as sts
from scipy.stats import linregress

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Save config information.

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %% [markdown]
# # Generate City List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 640

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Create lists for the dataframe
cities_list = []
cloudiness = []
dates = []
humidity = []
lats = []
lngs = []
max_temperature = []
wind_speed = []
countries = []

#Set initial count
counter = 0
set_count = 1

print("Beginning Data Retrieval")
print("--------------------------")

#if city is in the city list then get the data otherwise print the message of missing city.
for city in cities:
    print(f"Processing Record {counter} of Set {set_count} | {city}")

    # URL to request on
    final_url = query_url + city.replace(" ", "&")
    
    try:
        # Engage API, query, and cast to json      
        response = requests.get(final_url).json()

        # Populating lists with API data
        cloudiness.append(response["clouds"]["all"])
        countries.append(response["sys"]["country"])
        dates.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lats.append(response["coord"]["lat"])
        lngs.append(response["coord"]["lon"])
        max_temperature.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])

        # If record count below threshold, append, else
        if counter >= 50:
            counter = 1
            set_count +=1
            cities_list.append(city)
        else:
            counter += 1
            cities_list.append(city)
    except Exception:
        print("City not found. Skipping..")

        print("------------------------")
print("Data Retrieval Complete")
print("------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------
# Processing Record 0 of Set 1 | vaini
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | louisbourg
# City not found. Skipping..
# ------------------------
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | kaitangata
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | bailesti
# Processing Record 7 of Set 1 | pauini
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | sao filipe
# Processing Record 10 of Set 1 | gulshat
# City not found. Skipping..
# ------------------------
# Processing Record 10 of Set 1 | gorontalo
# Processing Record 11 of Set 1 | padang
# Processing Record 12 of Set 1 | fairbanks
# Processing Record 13 of Set 1 | attawapiskat
# City not found. Skipping..
# ------------------------
# Processing Record 13 of Set 1 | akusha
# Processing Record 14 of Set 1 | ibra
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | aktash
# Processing Record 19 of Set 1 | valley
# Processing Record 20 of Set 1 | airai
# Processing Record 21 of Set 1 | saint-augustin
# Processing Record 22 of Set 1 | belmonte
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | kirakira
# Processing Record 25 of Set 1 | lebyazhye
# Processing Record 26 of Set 1 | tachov
# Processing Record 27 of Set 1 | nabire
# Processing Record 28 of Set 1 | inhambane
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | tsihombe
# City not found. Skipping..
# ------------------------
# Processing Record 31 of Set 1 | upernavik
# Processing Record 32 of Set 1 | sabha
# Processing Record 33 of Set 1 | meyungs
# City not found. Skipping..
# ------------------------
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | hasaki
# Processing Record 36 of Set 1 | virpur
# Processing Record 37 of Set 1 | tumannyy
# City not found. Skipping..
# ------------------------
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | shelburne
# Processing Record 39 of Set 1 | severo-kurilsk
# Processing Record 40 of Set 1 | papayal
# Processing Record 41 of Set 1 | torbay
# Processing Record 42 of Set 1 | poum
# Processing Record 43 of Set 1 | morant bay
# Processing Record 44 of Set 1 | kraslava
# Processing Record 45 of Set 1 | loandjili
# Processing Record 46 of Set 1 | gazli
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | mahebourg
# Processing Record 50 of Set 1 | sorrento
# Processing Record 1 of Set 2 | norman wells
# Processing Record 2 of Set 2 | katsuura
# Processing Record 3 of Set 2 | esperance
# Processing Record 4 of Set 2 | gambela
# Processing Record 5 of Set 2 | laguna
# Processing Record 6 of Set 2 | risod
# Processing Record 7 of Set 2 | marcona
# City not found. Skipping..
# ------------------------
# Processing Record 7 of Set 2 | kazalinsk
# City not found. Skipping..
# ------------------------
# Processing Record 7 of Set 2 | umm kaddadah
# City not found. Skipping..
# ------------------------
# Processing Record 7 of Set 2 | belushya guba
# City not found. Skipping..
# ------------------------
# Processing Record 7 of Set 2 | artyk
# City not found. Skipping..
# ------------------------
# Processing Record 7 of Set 2 | candawaga
# City not found. Skipping..
# ------------------------
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | casablanca
# Processing Record 9 of Set 2 | barentsburg
# City not found. Skipping..
# ------------------------
# Processing Record 9 of Set 2 | oxford
# Processing Record 10 of Set 2 | ponta grossa
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | amderma
# City not found. Skipping..
# ------------------------
# Processing Record 13 of Set 2 | belyy yar
# Processing Record 14 of Set 2 | lavrentiya
# Processing Record 15 of Set 2 | guira de melena
# City not found. Skipping..
# ------------------------
# Processing Record 15 of Set 2 | ponta do sol
# Processing Record 16 of Set 2 | luderitz
# Processing Record 17 of Set 2 | kysyl-syr
# Processing Record 18 of Set 2 | umm lajj
# City not found. Skipping..
# ------------------------
# Processing Record 18 of Set 2 | victoria
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | langarud
# Processing Record 21 of Set 2 | rawson
# Processing Record 22 of Set 2 | los llanos de aridane
# City not found. Skipping..
# ------------------------
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | guadalupe y calvo
# Processing Record 24 of Set 2 | qasigiannguit
# Processing Record 25 of Set 2 | port elizabeth
# Processing Record 26 of Set 2 | kununurra
# Processing Record 27 of Set 2 | warman
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | anadyr
# Processing Record 30 of Set 2 | sao joao da barra
# Processing Record 31 of Set 2 | tiksi
# Processing Record 32 of Set 2 | bolshoye ignatovo
# City not found. Skipping..
# ------------------------
# Processing Record 32 of Set 2 | alofi
# Processing Record 33 of Set 2 | grand river south east
# Processing Record 34 of Set 2 | necochea
# Processing Record 35 of Set 2 | mar del plata
# Processing Record 36 of Set 2 | fukue
# Processing Record 37 of Set 2 | muswellbrook
# Processing Record 38 of Set 2 | mataura
# Processing Record 39 of Set 2 | gravelbourg
# Processing Record 40 of Set 2 | tuggurt
# City not found. Skipping..
# ------------------------
# Processing Record 40 of Set 2 | stokmarknes
# Processing Record 41 of Set 2 | armizonskoye
# Processing Record 42 of Set 2 | lagoa
# Processing Record 43 of Set 2 | chimbarongo
# Processing Record 44 of Set 2 | taolanaro
# City not found. Skipping..
# ------------------------
# Processing Record 44 of Set 2 | cedar city
# Processing Record 45 of Set 2 | ambulu
# Processing Record 46 of Set 2 | margate
# Processing Record 47 of Set 2 | longyearbyen
# Processing Record 48 of Set 2 | san quintin
# Processing Record 49 of Set 2 | faya
# Processing Record 50 of Set 2 | ler
# Processing Record 1 of Set 3 | staro nagoricane
# Processing Record 2 of Set 3 | catamarca
# Processing Record 3 of Set 3 | kuching
# Processing Record 4 of Set 3 | new norfolk
# Processing Record 5 of Set 3 | farah
# Processing Record 6 of Set 3 | aksu
# Processing Record 7 of Set 3 | tsabong
# Processing Record 8 of Set 3 | nikolskoye
# Processing Record 9 of Set 3 | umzimvubu
# City not found. Skipping..
# ------------------------
# Processing Record 9 of Set 3 | diapaga
# Processing Record 10 of Set 3 | cap malheureux
# Processing Record 11 of Set 3 | moranbah
# Processing Record 12 of Set 3 | avarua
# Processing Record 13 of Set 3 | kodiak
# Processing Record 14 of Set 3 | shubarkuduk
# Processing Record 15 of Set 3 | saldanha
# Processing Record 16 of Set 3 | grootfontein
# Processing Record 17 of Set 3 | lithakia
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | puerto rondon
# Processing Record 20 of Set 3 | hobart
# Processing Record 21 of Set 3 | lebu
# Processing Record 22 of Set 3 | port blair
# Processing Record 23 of Set 3 | ahipara
# Processing Record 24 of Set 3 | bonavista
# Processing Record 25 of Set 3 | georgetown
# Processing Record 26 of Set 3 | bilibino
# Processing Record 27 of Set 3 | dubbo
# Processing Record 28 of Set 3 | macaboboni
# City not found. Skipping..
# ------------------------
# Processing Record 28 of Set 3 | derzhavinsk
# Processing Record 29 of Set 3 | bilma
# Processing Record 30 of Set 3 | east london
# Processing Record 31 of Set 3 | wanaka
# Processing Record 32 of Set 3 | iqaluit
# Processing Record 33 of Set 3 | saint george
# City not found. Skipping..
# ------------------------
# Processing Record 33 of Set 3 | bonthe
# Processing Record 34 of Set 3 | sterling
# Processing Record 35 of Set 3 | ghanzi
# Processing Record 36 of Set 3 | honningsvag
# Processing Record 37 of Set 3 | princeton
# Processing Record 38 of Set 3 | meulaboh
# Processing Record 39 of Set 3 | talavera de la reina
# Processing Record 40 of Set 3 | port lincoln
# Processing Record 41 of Set 3 | carutapera
# Processing Record 42 of Set 3 | chuy
# Processing Record 43 of Set 3 | kruisfontein
# Processing Record 44 of Set 3 | tigil
# Processing Record 45 of Set 3 | yellowknife
# Processing Record 46 of Set 3 | mangit
# Processing Record 47 of Set 3 | ribeira brava
# Processing Record 48 of Set 3 | nizhneyansk
# City not found. Skipping..
# ------------------------
# Processing Record 48 of Set 3 | skibbereen
# Processing Record 49 of Set 3 | stromness
# Processing Record 50 of Set 3 | baoshan
# Processing Record 1 of Set 4 | mugur-aksy
# Processing Record 2 of Set 4 | labuhan
# Processing Record 3 of Set 4 | dolores
# Processing Record 4 of Set 4 | sao lourenco do oeste
# Processing Record 5 of Set 4 | pevek
# Processing Record 6 of Set 4 | ilulissat
# Processing Record 7 of Set 4 | illoqqortoormiut
# City not found. Skipping..
# ------------------------
# Processing Record 7 of Set 4 | polson
# Processing Record 8 of Set 4 | kouqian
# Processing Record 9 of Set 4 | paamiut
# Processing Record 10 of Set 4 | saleaula
# City not found. Skipping..
# ------------------------
# Processing Record 10 of Set 4 | mys shmidta
# Processing Record 11 of Set 4 | povoa de varzim
# Processing Record 12 of Set 4 | guerrero negro
# Processing Record 13 of Set 4 | port hardy
# Processing Record 14 of Set 4 | dori
# Processing Record 15 of Set 4 | port-gentil
# Processing Record 16 of Set 4 | port alfred
# Processing Record 17 of Set 4 | lebork
# Processing Record 18 of Set 4 | monrovia
# Processing Record 19 of Set 4 | whitehorse
# Processing Record 20 of Set 4 | vanavara
# Processing Record 21 of Set 4 | esna
# Processing Record 22 of Set 4 | tuktoyaktuk
# Processing Record 23 of Set 4 | supe
# Processing Record 24 of Set 4 | mentok
# City not found. Skipping..
# ------------------------
# Processing Record 24 of Set 4 | sioux lookout
# Processing Record 25 of Set 4 | saint-leu
# Processing Record 26 of Set 4 | ahuimanu
# Processing Record 27 of Set 4 | bubaque
# Processing Record 28 of Set 4 | safwah
# City not found. Skipping..
# ------------------------
# Processing Record 28 of Set 4 | ketchikan
# Processing Record 29 of Set 4 | constitucion
# Processing Record 30 of Set 4 | bandarbeyla
# Processing Record 31 of Set 4 | saskylakh
# Processing Record 32 of Set 4 | turbat
# Processing Record 33 of Set 4 | villa carlos paz
# Processing Record 34 of Set 4 | ust-kamchatsk
# City not found. Skipping..
# ------------------------
# Processing Record 34 of Set 4 | yar-sale
# Processing Record 35 of Set 4 | cabo san lucas
# Processing Record 36 of Set 4 | inta
# Processing Record 37 of Set 4 | kampot
# Processing Record 38 of Set 4 | komsomolskiy
# Processing Record 39 of Set 4 | xiangxiang
# Processing Record 40 of Set 4 | kurilsk
# Processing Record 41 of Set 4 | bonnyville
# Processing Record 42 of Set 4 | berlevag
# Processing Record 43 of Set 4 | geraldton
# Processing Record 44 of Set 4 | manjacaze
# Processing Record 45 of Set 4 | kavieng
# Processing Record 46 of Set 4 | vaitupu
# City not found. Skipping..
# ------------------------
# Processing Record 46 of Set 4 | yerbogachen
# Processing Record 47 of Set 4 | bethel
# Processing Record 48 of Set 4 | husavik
# Processing Record 49 of Set 4 | awbari
# Processing Record 50 of Set 4 | klaksvik
# Processing Record 1 of Set 5 | sola
# Processing Record 2 of Set 5 | morinville
# Processing Record 3 of Set 5 | sovetskiy
# Processing Record 4 of Set 5 | tasiilaq
# Processing Record 5 of Set 5 | imeni poliny osipenko
# Processing Record 6 of Set 5 | provideniya
# Processing Record 7 of Set 5 | fuxin
# Processing Record 8 of Set 5 | sahrak
# City not found. Skipping..
# ------------------------
# Processing Record 8 of Set 5 | makung
# City not found. Skipping..
# ------------------------
# Processing Record 8 of Set 5 | karachi
# Processing Record 9 of Set 5 | xining
# Processing Record 10 of Set 5 | plouzane
# Processing Record 11 of Set 5 | hovd
# Processing Record 12 of Set 5 | amapa
# Processing Record 13 of Set 5 | skjervoy
# Processing Record 14 of Set 5 | roros
# Processing Record 15 of Set 5 | salalah
# Processing Record 16 of Set 5 | narsaq
# Processing Record 17 of Set 5 | chenzhou
# Processing Record 18 of Set 5 | udhampur
# Processing Record 19 of Set 5 | nanakuli
# Processing Record 20 of Set 5 | fengkou
# Processing Record 21 of Set 5 | zelenoborskiy
# Processing Record 22 of Set 5 | kabalo
# Processing Record 23 of Set 5 | wenling
# Processing Record 24 of Set 5 | stockbridge
# Processing Record 25 of Set 5 | tidore
# City not found. Skipping..
# ------------------------
# Processing Record 25 of Set 5 | bokspits
# City not found. Skipping..
# ------------------------
# Processing Record 25 of Set 5 | kapit
# Processing Record 26 of Set 5 | bushehr
# Processing Record 27 of Set 5 | vao
# Processing Record 28 of Set 5 | itarema
# Processing Record 29 of Set 5 | kavaratti
# Processing Record 30 of Set 5 | lasa
# Processing Record 31 of Set 5 | fier
# Processing Record 32 of Set 5 | oktyabrskoye
# Processing Record 33 of Set 5 | bolshoy tsaryn
# City not found. Skipping..
# ------------------------
# Processing Record 33 of Set 5 | haines junction
# Processing Record 34 of Set 5 | vokhtoga
# Processing Record 35 of Set 5 | kyaikto
# Processing Record 36 of Set 5 | arman
# Processing Record 37 of Set 5 | saint-philippe
# Processing Record 38 of Set 5 | iraray
# Processing Record 39 of Set 5 | nhulunbuy
# Processing Record 40 of Set 5 | tukrah
# Processing Record 41 of Set 5 | kiruna
# Processing Record 42 of Set 5 | camacha
# Processing Record 43 of Set 5 | rolim de moura
# City not found. Skipping..
# ------------------------
# Processing Record 43 of Set 5 | kiskunhalas
# Processing Record 44 of Set 5 | west bay
# Processing Record 45 of Set 5 | dharapuram
# Processing Record 46 of Set 5 | hofn
# Processing Record 47 of Set 5 | praia da vitoria
# Processing Record 48 of Set 5 | vrangel
# Processing Record 49 of Set 5 | walvis bay
# City not found. Skipping..
# ------------------------
# Processing Record 49 of Set 5 | vila do maio
# Processing Record 50 of Set 5 | redcliffe
# Processing Record 1 of Set 6 | ericeira
# Processing Record 2 of Set 6 | quatre cocos
# City not found. Skipping..
# ------------------------
# Processing Record 2 of Set 6 | jhanjharpur
# Processing Record 3 of Set 6 | nome
# Processing Record 4 of Set 6 | raudeberg
# Processing Record 5 of Set 6 | ulladulla
# Processing Record 6 of Set 6 | thompson
# Processing Record 7 of Set 6 | hunza
# City not found. Skipping..
# ------------------------
# Processing Record 7 of Set 6 | salym
# Processing Record 8 of Set 6 | kangaatsiaq
# Processing Record 9 of Set 6 | wajima
# Processing Record 10 of Set 6 | sentyabrskiy
# City not found. Skipping..
# ------------------------
# Processing Record 10 of Set 6 | kholtoson
# Processing Record 11 of Set 6 | raga
# Processing Record 12 of Set 6 | ewa beach
# Processing Record 13 of Set 6 | tonj
# Processing Record 14 of Set 6 | lais
# Processing Record 15 of Set 6 | havoysund
# Processing Record 16 of Set 6 | manicore
# Processing Record 17 of Set 6 | rio grande
# Processing Record 18 of Set 6 | providencia
# Processing Record 19 of Set 6 | bengkulu
# Processing Record 20 of Set 6 | yinchuan
# Processing Record 21 of Set 6 | tutoia
# Processing Record 22 of Set 6 | mercedes
# Processing Record 23 of Set 6 | corrales
# Processing Record 24 of Set 6 | mahon
# Processing Record 25 of Set 6 | adeje
# Processing Record 26 of Set 6 | flin flon
# Processing Record 27 of Set 6 | reconquista
# Processing Record 28 of Set 6 | ambodifototra
# City not found. Skipping..
# ------------------------
# Processing Record 28 of Set 6 | xuddur
# Processing Record 29 of Set 6 | da nang
# City not found. Skipping..
# ------------------------
# Processing Record 29 of Set 6 | lompoc
# Processing Record 30 of Set 6 | keetmanshoop
# Processing Record 31 of Set 6 | chute-aux-outardes
# Processing Record 32 of Set 6 | buritis
# Processing Record 33 of Set 6 | khatanga
# Processing Record 34 of Set 6 | narrabri
# Processing Record 35 of Set 6 | aksarayskiy
# Processing Record 36 of Set 6 | natal
# Processing Record 37 of Set 6 | coahuayana
# Processing Record 38 of Set 6 | edmundston
# Processing Record 39 of Set 6 | portland
# Processing Record 40 of Set 6 | xichang
# Processing Record 41 of Set 6 | kahului
# Processing Record 42 of Set 6 | wucheng
# Processing Record 43 of Set 6 | buariki
# City not found. Skipping..
# ------------------------
# Processing Record 43 of Set 6 | hualmay
# Processing Record 44 of Set 6 | tsienyane
# City not found. Skipping..
# ------------------------
# Processing Record 44 of Set 6 | jaque
# Processing Record 45 of Set 6 | port said
# Processing Record 46 of Set 6 | chokurdakh
# Processing Record 47 of Set 6 | dzhusaly
# City not found. Skipping..
# ------------------------
# Processing Record 47 of Set 6 | broken hill
# City not found. Skipping..
# ------------------------
# Processing Record 47 of Set 6 | atar
# Processing Record 48 of Set 6 | buluang
# Processing Record 49 of Set 6 | oga
# Processing Record 50 of Set 6 | siderno
# Processing Record 1 of Set 7 | roald
# Processing Record 2 of Set 7 | corinto
# Processing Record 3 of Set 7 | saint-georges
# Processing Record 4 of Set 7 | zhezkazgan
# Processing Record 5 of Set 7 | la ronge
# City not found. Skipping..
# ------------------------
# Processing Record 5 of Set 7 | makokou
# Processing Record 6 of Set 7 | san carlos
# Processing Record 7 of Set 7 | mehamn
# Processing Record 8 of Set 7 | gigmoto
# Processing Record 9 of Set 7 | marsaxlokk
# Processing Record 10 of Set 7 | hobyo
# Processing Record 11 of Set 7 | daxian
# City not found. Skipping..
# ------------------------
# Processing Record 11 of Set 7 | okha
# Processing Record 12 of Set 7 | sao jose da coroa grande
# Processing Record 13 of Set 7 | tucupita
# Processing Record 14 of Set 7 | acapulco
# Processing Record 15 of Set 7 | conde
# Processing Record 16 of Set 7 | itupiranga
# Processing Record 17 of Set 7 | valparaiso
# Processing Record 18 of Set 7 | aurich
# Processing Record 19 of Set 7 | san cristobal
# Processing Record 20 of Set 7 | calama
# Processing Record 21 of Set 7 | sur
# Processing Record 22 of Set 7 | bairiki
# Processing Record 23 of Set 7 | sri aman
# Processing Record 24 of Set 7 | goure
# Processing Record 25 of Set 7 | maniitsoq
# Processing Record 26 of Set 7 | shakawe
# Processing Record 27 of Set 7 | luganville
# Processing Record 28 of Set 7 | chapais
# Processing Record 29 of Set 7 | terenos
# Processing Record 30 of Set 7 | sibolga
# Processing Record 31 of Set 7 | vila velha
# Processing Record 32 of Set 7 | tual
# Processing Record 33 of Set 7 | tautira
# Processing Record 34 of Set 7 | peleduy
# Processing Record 35 of Set 7 | lorengau
# Processing Record 36 of Set 7 | san patricio
# Processing Record 37 of Set 7 | isangel
# Processing Record 38 of Set 7 | vilcun
# Processing Record 39 of Set 7 | port shepstone
# Processing Record 40 of Set 7 | codrington
# Processing Record 41 of Set 7 | shasta lake
# Processing Record 42 of Set 7 | talnakh
# Processing Record 43 of Set 7 | narodychi
# Processing Record 44 of Set 7 | the valley
# City not found. Skipping..
# ------------------------
# Processing Record 44 of Set 7 | vostok
# Processing Record 45 of Set 7 | pitkyaranta
# Processing Record 46 of Set 7 | alamos
# Processing Record 47 of Set 7 | faanui
# Processing Record 48 of Set 7 | rio gallegos
# Processing Record 49 of Set 7 | vastervik
# City not found. Skipping..
# ------------------------
# Processing Record 49 of Set 7 | abha
# Processing Record 50 of Set 7 | zhenlai
# Processing Record 1 of Set 8 | satitoa
# City not found. Skipping..
# ------------------------
# Processing Record 1 of Set 8 | kamenskoye
# City not found. Skipping..
# ------------------------
# Processing Record 1 of Set 8 | goma
# Processing Record 2 of Set 8 | plainview
# Processing Record 3 of Set 8 | yuty
# Processing Record 4 of Set 8 | calvia
# Processing Record 5 of Set 8 | gzhatsk
# City not found. Skipping..
# ------------------------
# Processing Record 5 of Set 8 | pitimbu
# Processing Record 6 of Set 8 | fort-shevchenko
# Processing Record 7 of Set 8 | vikulovo
# Processing Record 8 of Set 8 | mumford
# Processing Record 9 of Set 8 | villarrobledo
# Processing Record 10 of Set 8 | manokwari
# Processing Record 11 of Set 8 | bucerias
# Processing Record 12 of Set 8 | nishihara
# Processing Record 13 of Set 8 | brigantine
# Processing Record 14 of Set 8 | vila franca do campo
# Processing Record 15 of Set 8 | sambava
# Processing Record 16 of Set 8 | andra
# Processing Record 17 of Set 8 | goderich
# Processing Record 18 of Set 8 | zhigansk
# Processing Record 19 of Set 8 | sitangkai
# Processing Record 20 of Set 8 | beloha
# Processing Record 21 of Set 8 | vigrestad
# Processing Record 22 of Set 8 | hongjiang
# Processing Record 23 of Set 8 | dingle
# Processing Record 24 of Set 8 | manta
# Processing Record 25 of Set 8 | jinka
# Processing Record 26 of Set 8 | ronneby
# Processing Record 27 of Set 8 | araouane
# Processing Record 28 of Set 8 | sept-iles
# Processing Record 29 of Set 8 | ust-kuyga
# Processing Record 30 of Set 8 | imbituba
# Processing Record 31 of Set 8 | tangshan
# Processing Record 32 of Set 8 | naze
# Processing Record 33 of Set 8 | vauvert
# Processing Record 34 of Set 8 | fare
# Processing Record 35 of Set 8 | te anau
# City not found. Skipping..
# ------------------------
# Processing Record 35 of Set 8 | shibarghan
# City not found. Skipping..
# ------------------------
# Processing Record 35 of Set 8 | bria
# Processing Record 36 of Set 8 | bambous virieux
# Processing Record 37 of Set 8 | zaterechnyy
# Processing Record 38 of Set 8 | ilo
# Processing Record 39 of Set 8 | masterton
# Processing Record 40 of Set 8 | tilichiki
# Processing Record 41 of Set 8 | tarlisua
# City not found. Skipping..
# ------------------------
# Processing Record 41 of Set 8 | bako
# Processing Record 42 of Set 8 | ambilobe
# Processing Record 43 of Set 8 | yilan
# Processing Record 44 of Set 8 | beyneu
# Processing Record 45 of Set 8 | wukari
# Processing Record 46 of Set 8 | ancud
# Processing Record 47 of Set 8 | moerai
# Processing Record 48 of Set 8 | drayton valley
# Processing Record 49 of Set 8 | guanica
# Processing Record 50 of Set 8 | khasan
# Processing Record 1 of Set 9 | abu jubayhah
# Processing Record 2 of Set 9 | san nicolas
# Processing Record 3 of Set 9 | boende
# Processing Record 4 of Set 9 | preobrazheniye
# Processing Record 5 of Set 9 | xai-xai
# Processing Record 6 of Set 9 | kayerkan
# Processing Record 7 of Set 9 | yanam
# Processing Record 8 of Set 9 | dire dawa
# Processing Record 9 of Set 9 | prince george
# Processing Record 10 of Set 9 | bosaso
# Processing Record 11 of Set 9 | pavino
# Processing Record 12 of Set 9 | ourinhos
# Processing Record 13 of Set 9 | sena madureira
# Processing Record 14 of Set 9 | itoman
# Processing Record 15 of Set 9 | samusu
# City not found. Skipping..
# ------------------------
# Processing Record 15 of Set 9 | acari
# Processing Record 16 of Set 9 | orekhovo-zuevo
# Processing Record 17 of Set 9 | concepcion del oro
# Processing Record 18 of Set 9 | puerto leguizamo
# Processing Record 19 of Set 9 | perry
# Processing Record 20 of Set 9 | staryy nadym
# City not found. Skipping..
# ------------------------
# Processing Record 20 of Set 9 | wagar
# Processing Record 21 of Set 9 | neryungri
# Processing Record 22 of Set 9 | mecca
# Processing Record 23 of Set 9 | halifax
# Processing Record 24 of Set 9 | gweta
# Processing Record 25 of Set 9 | cody
# Processing Record 26 of Set 9 | roma
# Processing Record 27 of Set 9 | pskent
# City not found. Skipping..
# ------------------------
# Processing Record 27 of Set 9 | hienghene
# Processing Record 28 of Set 9 | gornopravdinsk
# Processing Record 29 of Set 9 | pijijiapan
# Processing Record 30 of Set 9 | richards bay
# Processing Record 31 of Set 9 | muroto
# Processing Record 32 of Set 9 | juba
# Processing Record 33 of Set 9 | leninskoye
# Processing Record 34 of Set 9 | chhindwara
# Processing Record 35 of Set 9 | camacupa
# Processing Record 36 of Set 9 | touros
# Processing Record 37 of Set 9 | skage
# City not found. Skipping..
# ------------------------
# Processing Record 37 of Set 9 | muscle shoals
# City not found. Skipping..
# ------------------------
# Processing Record 37 of Set 9 | kalmunai
# Processing Record 38 of Set 9 | cracaoani
# City not found. Skipping..
# ------------------------
# Processing Record 38 of Set 9 | jinxiang
# Processing Record 39 of Set 9 | aykhal
# Processing Record 40 of Set 9 | pacific grove
# Processing Record 41 of Set 9 | batemans bay
# City not found. Skipping..
# ------------------------
# Processing Record 41 of Set 9 | muzhi
# Processing Record 42 of Set 9 | arlit
# Processing Record 43 of Set 9 | bagdarin
# Processing Record 44 of Set 9 | lolua
# City not found. Skipping..
# ------------------------
# Processing Record 44 of Set 9 | sistranda
# Processing Record 45 of Set 9 | diego de almagro
# City not found. Skipping..
# ------------------------
# Processing Record 45 of Set 9 | sarany
# Processing Record 46 of Set 9 | ruteng
# Processing Record 47 of Set 9 | katra
# Processing Record 48 of Set 9 | cam ranh
# Processing Record 49 of Set 9 | tiarei
# Processing Record 50 of Set 9 | domoni
# Processing Record 1 of Set 10 | tuatapere
# Processing Record 2 of Set 10 | comodoro rivadavia
# Processing Record 3 of Set 10 | tefe
# Processing Record 4 of Set 10 | souillac
# Processing Record 5 of Set 10 | san policarpo
# Processing Record 6 of Set 10 | gazanjyk
# Processing Record 7 of Set 10 | chipata
# Processing Record 8 of Set 10 | cherskiy
# Processing Record 9 of Set 10 | dharchula
# Processing Record 10 of Set 10 | soyo
# Processing Record 11 of Set 10 | slupsk
# Processing Record 12 of Set 10 | fortuna
# Processing Record 13 of Set 10 | johnstown
# Processing Record 14 of Set 10 | barra patuca
# Processing Record 15 of Set 10 | presidencia roque saenz pena
# City not found. Skipping..
# ------------------------
# Processing Record 15 of Set 10 | olafsvik
# Processing Record 16 of Set 10 | agua caliente de linaca
# Processing Record 17 of Set 10 | hami
# Processing Record 18 of Set 10 | makakilo city
# Processing Record 19 of Set 10 | virginia beach
# Processing Record 20 of Set 10 | carman
# Processing Record 21 of Set 10 | ondangwa
# Processing Record 22 of Set 10 | norsup
# Processing Record 23 of Set 10 | finnentrop
# Processing Record 24 of Set 10 | nyurba
# Processing Record 25 of Set 10 | lakes entrance
# Processing Record 26 of Set 10 | fuerte olimpo
# Processing Record 27 of Set 10 | eidfjord
# Processing Record 28 of Set 10 | purpe
# Processing Record 29 of Set 10 | abu samrah
# Processing Record 30 of Set 10 | jahrom
# City not found. Skipping..
# ------------------------
# Processing Record 30 of Set 10 | biltine
# Processing Record 31 of Set 10 | dilla
# Processing Record 32 of Set 10 | saint-joseph
# Processing Record 33 of Set 10 | asau
# Processing Record 34 of Set 10 | niquelandia
# Processing Record 35 of Set 10 | marawi
# Processing Record 36 of Set 10 | phenix city
# Processing Record 37 of Set 10 | tucuman
# Processing Record 38 of Set 10 | fort nelson
# Processing Record 39 of Set 10 | antofagasta
# Processing Record 40 of Set 10 | leshukonskoye
# Processing Record 41 of Set 10 | popondetta
# Processing Record 42 of Set 10 | dicabisagan
# Processing Record 43 of Set 10 | kijang
# Processing Record 44 of Set 10 | moose factory
# Processing Record 45 of Set 10 | bur gabo
# Processing Record 46 of Set 10 | brae
# Processing Record 47 of Set 10 | puerto escondido
# Processing Record 48 of Set 10 | cidreira
# Processing Record 49 of Set 10 | saint-francois
# Processing Record 50 of Set 10 | waipawa
# Processing Record 1 of Set 11 | ijaki
# City not found. Skipping..
# ------------------------
# Processing Record 1 of Set 11 | hearst
# Processing Record 2 of Set 11 | yeppoon
# Processing Record 3 of Set 11 | surt
# Processing Record 4 of Set 11 | tevriz
# Processing Record 5 of Set 11 | sorvag
# City not found. Skipping..
# ------------------------
# Processing Record 5 of Set 11 | honiara
# Processing Record 6 of Set 11 | krasnyy chikoy
# Processing Record 7 of Set 11 | barbatesti
# Processing Record 8 of Set 11 | hue
# Processing Record 9 of Set 11 | harper
# Processing Record 10 of Set 11 | khandyga
# Processing Record 11 of Set 11 | nogliki
# Processing Record 12 of Set 11 | lamu
# Processing Record 13 of Set 11 | qaqortoq
# Processing Record 14 of Set 11 | gizo
# Processing Record 15 of Set 11 | kalengwa
# Processing Record 16 of Set 11 | olecko
# Processing Record 17 of Set 11 | smithers
# Processing Record 18 of Set 11 | bethanien
# Processing Record 19 of Set 11 | ozernovskiy
# Processing Record 20 of Set 11 | djibo
# Processing Record 21 of Set 11 | mackay
# Processing Record 22 of Set 11 | flinders
# Processing Record 23 of Set 11 | puerto del rosario
# Processing Record 24 of Set 11 | nanortalik
# Processing Record 25 of Set 11 | kobryn
# Processing Record 26 of Set 11 | clyde river
# Processing Record 27 of Set 11 | yumen
# Processing Record 28 of Set 11 | half moon bay
# Processing Record 29 of Set 11 | bundaberg
# Processing Record 30 of Set 11 | mezen
# Processing Record 31 of Set 11 | pisco
# Processing Record 32 of Set 11 | kungurtug
# Processing Record 33 of Set 11 | henties bay
# City not found. Skipping..
# ------------------------
# Processing Record 33 of Set 11 | hanzhong
# Processing Record 34 of Set 11 | vadinsk
# Processing Record 35 of Set 11 | bang rakam
# Processing Record 36 of Set 11 | tuysarkan
# City not found. Skipping..
# ------------------------
# Processing Record 36 of Set 11 | jacupiranga
# Processing Record 37 of Set 11 | cairns
# Processing Record 38 of Set 11 | djambala
# Processing Record 39 of Set 11 | eureka
# Processing Record 40 of Set 11 | la union
# City not found. Skipping..
# ------------------------
# Processing Record 40 of Set 11 | itagi
# Processing Record 41 of Set 11 | magway
# Processing Record 42 of Set 11 | karratha
# Processing Record 43 of Set 11 | san jeronimo
# Processing Record 44 of Set 11 | havre-saint-pierre
# Processing Record 45 of Set 11 | prado
# Processing Record 46 of Set 11 | leticia
# Processing Record 47 of Set 11 | krasnoarmeyskiy
# Processing Record 48 of Set 11 | eyl
# Processing Record 49 of Set 11 | tabiauea
# City not found. Skipping..
# ------------------------
# Processing Record 49 of Set 11 | tessalit
# Processing Record 50 of Set 11 | athabasca
# Processing Record 1 of Set 12 | bahia blanca
# Processing Record 2 of Set 12 | aquin
# Processing Record 3 of Set 12 | nizhniy bestyakh
# Processing Record 4 of Set 12 | addi ugri
# Processing Record 5 of Set 12 | arti
# Processing Record 6 of Set 12 | segou
# Processing Record 7 of Set 12 | hirara
# Processing Record 8 of Set 12 | ust-kulom
# Processing Record 9 of Set 12 | lufkin
# Processing Record 10 of Set 12 | nuevo ideal
# Processing Record 11 of Set 12 | longlac
# City not found. Skipping..
# ------------------------
# Processing Record 11 of Set 12 | lata
# Processing Record 12 of Set 12 | vardo
# Processing Record 13 of Set 12 | zverinogolovskoye
# Processing Record 14 of Set 12 | durango
# Processing Record 15 of Set 12 | phalodi
# Data Retrieval Complete
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create the DataFrame
weather_df = pd.DataFrame({
    "City" : cities_list,
    "Cloudiness" : cloudiness,
    "Country" : countries,
    "Date" : dates,
    "Humidity" : humidity,
    "Latitude" : lats,
    "Longitude" : lngs,
    "Max Temperature" : max_temperature,
    "Wind Speed" : wind_speed})
weather_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity  Latitude  Longitude  \
# 0       vaini          20      TO  1607396854        74    -21.20    -175.20
# 1     ushuaia          90      AR  1607396854        93    -54.80     -68.30
# 2       kapaa          75      US  1607396854        74     22.08    -159.32
# 3  butaritari          42      KI  1607396855        76      3.07     172.79
# 4  kaitangata          39      NZ  1607396855        53    -46.28     169.85
#
#    Max Temperature  Wind Speed
# 0            84.20       10.29
# 1            44.60       16.11
# 2            80.60       13.87
# 3            81.79        8.46
# 4            69.01       10.00

# %%
weather_df.count()
# Out:
# City               566
# Cloudiness         566
# Country            566
# Date               566
# Humidity           566
# Latitude           566
# Longitude          566
# Max Temperature    566
# Wind Speed         566
# dtype: int64

# %%
#Exporting dataframe into csv
weather_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity  Latitude  Longitude  \
# 0       vaini          20      TO  1607396854        74    -21.20    -175.20
# 1     ushuaia          90      AR  1607396854        93    -54.80     -68.30
# 2       kapaa          75      US  1607396854        74     22.08    -159.32
# 3  butaritari          42      KI  1607396855        76      3.07     172.79
# 4  kaitangata          39      NZ  1607396855        53    -46.28     169.85
#
#    Max Temperature  Wind Speed
# 0            84.20       10.29
# 1            44.60       16.11
# 2            80.60       13.87
# 3            81.79        8.46
# 4            69.01       10.00

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Scatter plot for Latitude vs. Temperature using Matplotlib
ax = plt.axes
plt.scatter(weather_df["Latitude"], weather_df["Max Temperature"], marker= "o", edgecolor = "BLACK", FACECOLOR="BLUE", linewidths=1, alpha=0.8)
ax.set_facecolor("grey")
plt.title("City Latitude vs. Temperature (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.xlim(-60, 80)
plt.ylim(0,105)
plt.savefig("Figure1.png")
plt.show()
# Out:
# <ipython-input-23-91962bb2f95a>:3: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.scatter(weather_df["Latitude"], weather_df["Max Temperature"], marker= "o", edgecolor = "BLACK", FACECOLOR="BLUE", linewidths=1, alpha=0.8)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-91962bb2f95a> in <module>
#       2 ax = plt.axes
#       3 plt.scatter(weather_df["Latitude"], weather_df["Max Temperature"], marker= "o", edgecolor = "BLACK", FACECOLOR="BLUE", linewidths=1, alpha=0.8)
# ----> 4 ax.set_facecolor("grey")
#       5 plt.title("City Latitude vs. Temperature (%s)" % time.strftime("%x"))
#       6 plt.xlabel("Latitude")
#
# AttributeError: 'function' object has no attribute 'set_facecolor'

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#Scatter plot for Latitude vs. Humidity using Matplotlib
plt.scatter(weather_df["Latitude"], weather_df["Humidity"], marker= "o", edgecolor = "black", facecolor = "lightblue")
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.xlim(-60, 80)
plt.ylim(15,105)
plt.grid(b=True, axis = "both", linestyle= "-", color="lightgrey")
plt.savefig("Figure2.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Scatter plot for Latitude vs. Cloudiness using Matplotlib
plt.scatter(weather_df["Latitude"], weather_df["Cloudiness"], marker= "o", edgecolor = "black", facecolor = "lightblue")
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.xlim(-60, 80)
plt.ylim(15,105)
plt.grid(b=True, axis = "both", linestyle= "-", color="lightgrey")
plt.savefig("Figure3.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#Scatter plot for Latitude vs. Wind Speed using Matplotlib
plt.scatter(weather_df["Latitude"], weather_df["Wind Speed"], marker= "o", edgecolor = "black", facecolor = "lightblue")
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.xlim(-60, 80)
#plt.ylim(0,35)
plt.grid(b=True, axis = "both", linestyle= "-", color="lightgrey")
plt.savefig("Figure4.png")
plt.show()

# %%
#Northern and Southern Hemispehere
northern_hemisphere = weather_df.loc[weather_df["Latitude"] >= 0]
southern_hemisphere = weather_df.loc[weather_df["Latitude"] < 0]

# %%
#Linear Regression for Max Temperature and Latitude in the Northern Hemisphere
correlation = sts.pearsonr(northern_hemisphere["Latitude"], northern_hemisphere["Max Temperature"])
print(f"The correlation between both factors is {round(correlation[0],4)}")

x_values = northern_hemisphere["Latitude"]
y_values = northern_hemisphere["Max Temperature"]

slope, intercept, rvalue, pvalue, std = sts.linregress(x_values, y_values)
regress_values = slope * x_values + intercept
eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,color="red")
plt.annotate(eq, (10,40), fontsize= 8, color="red")
plt.title("Northern Hemisphere- Max Temperature vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.savefig("Linear Regression- Latitude vs. Max Temperature.png")
plt.grid(True)
plt.show()
# Out:
# The correlation between both factors is -0.8607

# %%
#Linear Regression for Max Temperature and Latitude in the Southern Hemisphere
correlation = sts.pearsonr(southern_hemisphere["Latitude"], southern_hemisphere["Max Temperature"])
print(f"The correlation between both factors is {round(correlation[0],4)}")

x_values = southern_hemisphere["Latitude"]
y_values = southern_hemisphere["Max Temperature"]

slope, intercept, rvalue, pvalue, std = sts.linregress(x_values, y_values)
regress_values = slope * x_values + intercept
eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,color="red")
plt.annotate(eq, (-20,50), fontsize= 8, color="red")
plt.title("Southern Hemisphere- Max Temperature vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.savefig("Linear Regression- Latitude vs. Max Temperature.png")
plt.grid(True)
plt.show()
# Out:
# The correlation between both factors is 0.6577

# %%
#Linear Regression for Humidity and Latitude in the Northern Hemisphere
correlation = sts.pearsonr(northern_hemisphere["Latitude"], northern_hemisphere["Humidity"])
print(f"The correlation between both factors is {round(correlation[0],4)}")

x_values = northern_hemisphere["Latitude"]
y_values = northern_hemisphere["Humidity"]

slope, intercept, rvalue, pvalue, std = sts.linregress(x_values, y_values)
regress_values = slope * x_values + intercept
eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,color="red")
plt.annotate(eq, (50,20), fontsize= 8, color="red")
plt.title("Northern Hemisphere- Latitude vs. Humidity Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.savefig("Linear Regression- Latitude vs. Humidity.png")
plt.grid(True)
plt.show()
# Out:
# The correlation between both factors is 0.2327

# %%
#Linear Regression for Humidity and Latitude in the Southern Hemisphere
correlation = sts.pearsonr(southern_hemisphere["Latitude"], southern_hemisphere["Humidity"])
print(f"The correlation between both factors is {round(correlation[0],4)}")

x_values = southern_hemisphere["Latitude"]
y_values = southern_hemisphere["Humidity"]

slope, intercept, rvalue, pvalue, std = sts.linregress(x_values, y_values)
regress_values = slope * x_values + intercept
eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,color="red")
plt.annotate(eq, (-20,30), fontsize= 8, color="red")
plt.title("Southern Hemisphere- Latitude vs. Humidity Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.savefig("Linear Regression- Latitude vs. Humidity.png")
plt.grid(True)
plt.show()
# Out:
# The correlation between both factors is 0.1513

# %%
#Linear Regression for Cloudiness and Latitude in the Northern Hemisphere
correlation = sts.pearsonr(northern_hemisphere["Latitude"], northern_hemisphere["Cloudiness"])
print(f"The correlation between both factors is {round(correlation[0],4)}")

x_values = northern_hemisphere["Latitude"]
y_values = northern_hemisphere["Cloudiness"]

slope, intercept, rvalue, pvalue, std = sts.linregress(x_values, y_values)
regress_values = slope * x_values + intercept
eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,color="red")
plt.annotate(eq, (50,30), fontsize= 8, color="red")
plt.title("Northern Hemisphere- Latitude vs. Cloudiness Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.savefig("Linear Regression- Latitude vs. Cloudiness.png")
plt.grid(True)
plt.show()
# Out:
# The correlation between both factors is 0.1834

# %%
#Linear Regression for Cloudiness and Latitude in the Southern Hemisphere
correlation = sts.pearsonr(southern_hemisphere["Latitude"], southern_hemisphere["Cloudiness"])
print(f"The correlation between both factors is {round(correlation[0],4)}")

x_values = southern_hemisphere["Latitude"]
y_values = southern_hemisphere["Cloudiness"]

slope, intercept, rvalue, pvalue, std = sts.linregress(x_values, y_values)
regress_values = slope * x_values + intercept
eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,color="red")
plt.annotate(eq, (-30,50), fontsize= 8, color="red")
plt.title("Northern Hemisphere- Latitude vs. Cloudiness Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.savefig("Linear Regression- Latitude vs. Cloudiness.png")
plt.grid(True)
plt.show()
# Out:
# The correlation between both factors is -0.0314

# %%
#Linear Regression for Wind Speed and Latitude in the Northern Hemisphere
correlation = sts.pearsonr(northern_hemisphere["Latitude"], northern_hemisphere["Wind Speed"])
print(f"The correlation between both factors is {round(correlation[0],4)}")

x_values = northern_hemisphere["Latitude"]
y_values = northern_hemisphere["Wind Speed"]

slope, intercept, rvalue, pvalue, std = sts.linregress(x_values, y_values)
regress_values = slope * x_values + intercept
eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,color="red")
plt.annotate(eq, (50,40), fontsize= 8, color="red")
plt.title("Northern Hemisphere- Latitude vs. Wind Speed Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.savefig("Linear Regression- Latitude vs. Wind Speed.png")
plt.grid(True)
plt.show()
# Out:
# The correlation between both factors is 0.2556

# %%
#Linear Regression for Wind Speed and Latitude in the Southern Hemisphere
correlation = sts.pearsonr(southern_hemisphere["Latitude"], southern_hemisphere["Wind Speed"])
print(f"The correlation between both factors is {round(correlation[0],4)}")

x_values = southern_hemisphere["Latitude"]
y_values = southern_hemisphere["Wind Speed"]

slope, intercept, rvalue, pvalue, std = sts.linregress(x_values, y_values)
regress_values = slope * x_values + intercept
eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,color="red")
plt.annotate(eq, (-50,10), fontsize= 8, color="red")
plt.title("Southern Hemisphere- Latitude vs. Wind Speed Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.savefig("Linear Regression- Latitude vs. Wind Speed.png")
plt.grid(True)
plt.show()
# Out:
# The correlation between both factors is -0.2925
